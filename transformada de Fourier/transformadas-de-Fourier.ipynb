# %% [markdown]
# # Ejemplos de Tranformadas de Fourier N2

# %% [markdown]
# ![](tabla2.png)

# %%
# Importar librerias basicas
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %matplotlib inline
plt.style.use('bmh') # estilo de las graficas
from IPython.display import Latex # para visualizar ecuaciones en jupyter

# %%
sym.init_printing()

t, w = sym.symbols('t omega', real=True)
w0 = sym.symbols('omega_0', real= True)
T = 2

def fourier_transform(x):
    return sym.transforms._fourier_transform(x, t, w, 1, -1, 'Fourier')

# %% [markdown]
# # 6. Transformada de Fourier
#
# $\large f(t) = \mu (t)$
#
# para $a = 1$

# %%
a = sym.Heaviside(t)
sym.plot(a, (t, -1, 6), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.Heaviside(t))
FW
# Out:
# ---------------------------------------------------------------------------
# IntegralTransformError                    Traceback (most recent call last)
# <ipython-input-4-1dc98ebf2329> in <module>
# ----> 1 FW = fourier_transform(sym.Heaviside(t))
#       2 FW
#
# <ipython-input-2-ca8c0404e8d3> in fourier_transform(x)
#       6
#       7 def fourier_transform(x):
# ----> 8     return sym.transforms._fourier_transform(x, t, w, 1, -1, 'Fourier')
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\transforms.py in wrapper(*args, **kwargs)
#     202         def wrapper(*args, **kwargs):
#     203             noconds = kwargs.pop('noconds', default)
# --> 204             res = func(*args, **kwargs)
#     205             if noconds:
#     206                 return res[0]
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\transforms.py in _fourier_transform(f, x, k, a, b, name, simplify)
#    1308     integral_f = integrate(f, (x, -oo, oo))
#    1309     if integral_f in (-oo, oo, S.NaN) or integral_f.has(Integral):
# -> 1310         raise IntegralTransformError(name, f, 'function not integrable on real axis')
#    1311
#    1312     if not F.is_Piecewise:
#
# IntegralTransformError: Fourier Transform could not be computed: function not integrable on real axis.

# %%
sym.plot(sym.Abs(FW), (w, -40, 40), xlabel=r'$\omega$', ylabel=r'$|X(j\omega)|$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-43946145fa5a> in <module>
# ----> 1 sym.plot(sym.Abs(FW), (w, -40, 40), xlabel=r'$\omega$', ylabel=r'$|X(j\omega)|$')
#
# NameError: name 'FW' is not defined

# %% [markdown]
# # 7. Transformada de Fourier
#
# $\large f(t) = \cos{\omega_0 t} \mu (t)$
#
# para $a = 1$

# %%
a = sym.cos((sym.pi*2/T)*t)*sym.Heaviside(t)
sym.plot(a, (t, -1, 6), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.cos((sym.pi*2/T)*t)*sym.Heaviside(t))
FW
# Out:
#  -ⅈ⋅ω
# ───────
#  2    2
# ω  - π

# %%
FW = fourier_transform(sym.cos(w0*t)*sym.Heaviside(t))
FW

# %%
sym.plot(sym.Abs(FW), (w, -10, 10), xlabel=r'$\omega$', ylabel=r'$|X(j\omega)|$')

# %%
sym.plot(sym.arg(FW), (w, -30, 30), xlabel=r'$\omega$', ylabel=r'$\angle X(j\omega)$')

# %% [markdown]
# # 8. Transformada de Fourier
#
# $\large f(t) = \sin{\omega_0 t} \mu (t)$
#
# para $a = 1$

# %%
a = sym.sin((sym.pi*2/T)*t)*sym.Heaviside(t)
sym.plot(a, (t, -1, 6), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.sin((sym.pi*2/T)*t)*sym.Heaviside(t))
FW
# Out:
#   -π
# ───────
#  2    2
# ω  - π

# %%
FW = fourier_transform(sym.sin(w0*t)*sym.Heaviside(t))
FW
# Out:
# ---------------------------------------------------------------------------
# IntegralTransformError                    Traceback (most recent call last)
# <ipython-input-12-8c506e0c7732> in <module>
# ----> 1 FW = fourier_transform(sym.sin(w0*t)*sym.Heaviside(t))
#       2 FW
#
# <ipython-input-2-ca8c0404e8d3> in fourier_transform(x)
#       6
#       7 def fourier_transform(x):
# ----> 8     return sym.transforms._fourier_transform(x, t, w, 1, -1, 'Fourier')
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\transforms.py in wrapper(*args, **kwargs)
#     202         def wrapper(*args, **kwargs):
#     203             noconds = kwargs.pop('noconds', default)
# --> 204             res = func(*args, **kwargs)
#     205             if noconds:
#     206                 return res[0]
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\transforms.py in _fourier_transform(f, x, k, a, b, name, simplify)
#    1308     integral_f = integrate(f, (x, -oo, oo))
#    1309     if integral_f in (-oo, oo, S.NaN) or integral_f.has(Integral):
# -> 1310         raise IntegralTransformError(name, f, 'function not integrable on real axis')
#    1311
#    1312     if not F.is_Piecewise:
#
# IntegralTransformError: Fourier Transform could not be computed: function not integrable on real axis.

# %% [markdown]
# # 9. Transformada de Fourier
#
# $\large f(t) = \cos{\omega_0 t}$
#
# para $a = 1$

# %%
a = sym.cos((sym.pi*2/T)*t)
sym.plot(a, (t, -1, 6), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.cos((sym.pi*2/T)*t))
FW
# Out:
# 0

# %%
FW = fourier_transform(sym.cos(w0*t))
FW
# Out:
# 0

# %% [markdown]
# # 10. Transformada de Fourier
#
# $\large f(t) = \sin{\omega_0 t}$
#
# para $a = 1$

# %%
a = sym.sin((sym.pi*2/T)*t)
sym.plot(a, (t, -1, 6), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.sin(w0*t))
FW
# Out:
# 0

# %% [markdown]
# ### 11. Transformada de Fourier
#
# $\large f(t) = e^{-at} \sin{\omega_0 t} \mu(t)$
#
# para $a = 1$

# %%
a = sym.exp(-t) * sym.sin((sym.pi*2/T) * t) * sym.Heaviside(t) 
sym.plot(a, (t, -2, 10), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.exp(-t) * sym.sin((sym.pi*2/T) * t) * sym.Heaviside(t))
FW
# Out:
#        π
# ───────────────
#          2    2
# (ⅈ⋅ω + 1)  + π

# %%
FW = fourier_transform(sym.sin(t) * sym.exp(-t) * sym.Heaviside(t))
FW
# Out:
#       1
# ──────────────
#          2
# (ⅈ⋅ω + 1)  + 1

# %% [markdown]
# ### 15. Transformada de Fourier
#
# $\large f(t) = e^{-a|t|} $
#
# para $a = 1$

# %%
a = sym.exp(abs(t)) 
sym.plot(a, (t, -10, 10), xlabel=r'$t$', ylabel=r'$f(t)$')

# %%
FW = fourier_transform(sym.exp(-1*sym.Abs(t)))
FW
# Out:
#   2
# ──────
#  2
# ω  + 1
